# %%
import geocoder
import pandas as pd
import numpy as np
import re

# %% [markdown]
# Load datasets. The cities are grabbed from 3 datasets on Sept 10.

# %%
df = pd.concat([pd.read_csv('cleansed_data/baseline_00.csv')[['region name', 'lon', 'lat']],
                pd.read_csv('cleansed_data/baseline_08.csv')[['region name', 'lon', 'lat']],
                pd.read_csv('cleansed_data/baseline_16.csv')[['region name', 'lon', 'lat']]], ignore_index=True)

# %% [markdown]
# Take mean value for the lon, lat

# %%
regions = df.groupby('region name').mean().reset_index()

# %%
regions.head()
# Out:
#    region name        lon        lat
# 0  Abbeville_1 -82.448461  34.203223
# 1  Abbeville_5 -83.431289  31.933351
# 2   Aberdeen_2 -83.716002  38.708632
# 3   Aberdeen_3 -79.415092  35.101738
# 4   Aberdeen_4 -79.410768  35.054672

# %% [markdown]
# 2 methods are used here to find county and state of the region.

# %% [markdown]
# First, use reverse geocoding

# %%
county = []
state = []
for i in range(regions.shape[0]):
    loc = geocoder.mapquest([regions['lat'].iloc[i], regions['lon'].iloc[i]], method='reverse', key='sC87jHB8CsRXTnfhb1I123jsWgSW62tt').json
    county.append(loc['county'])
    state.append(loc['state'])

# %%
regions['county'] = county
regions['state'] = state

# %%
regions.head()
# Out:
#    region name        lon        lat     county state     evacuation
# 0  Abbeville_1 -82.448461  34.203223  Abbeville    SC  no evacuation
# 1  Abbeville_5 -83.431289  31.933351     Wilcox    GA  no evacuation
# 2   Aberdeen_2 -83.716002  38.708632      Brown    OH  no evacuation
# 3   Aberdeen_3 -79.415092  35.101738      Moore    NC  no evacuation
# 4   Aberdeen_4 -79.410768  35.054672       Hoke    NC  no evacuation

# %% [markdown]
# Second, use geocoding confined in a bounding box

# %%
county_here = []
state_here = []
lon_here = []
lat_here = []
for i in range(regions.shape[0]):
    lon = regions['lon'].iloc[i]
    lat = regions['lat'].iloc[i]
    if re.match('[^_]+_[^_]+_[^_]+', regions['region name'].iloc[i])!=None:
        county_here.append(county[i])
        state_here.append(state[i])
        lon_here.append(lon)
        lat_here.append(lat)
    else:
        loc_name = re.sub('_\d+', '', regions['region name'].iloc[i])
        if re.match('^Mc', loc_name)!=None:
            loc_name = re.sub(' ', '', loc_name)
        bbox = [lon-0.25, lat-0.25, lon+0.25, lat+0.25]
        try:
            loc = geocoder.here(loc_name, bbox=bbox, app_id='xIirayHrtGRTzhFhowWm', app_code='PHY3HgiT4QsGtpMPUA_tRA').json
            county_here.append(loc['county'])
            state_here.append(loc['state'])
            lon_here.append(loc['lng'])
            lat_here.append(loc['lat'])
        except:
            county_here.append('unknown')
            state_here.append('unknown')
            lon_here.append(-1)
            lat_here.append(-1)

# %%
regions['county_here'] = county_here
regions['state_here'] = state_here
regions['lon_here'] = lon_here
regions['lat_here'] = lat_here

# %%
idx = regions[regions['county_here']=='unknown'].index
for i in idx:
    lon = regions['lon'].loc[i]
    lat = regions['lat'].loc[i]
    loc_name = re.sub('_\d+', '', regions['region name'].loc[i])
    bbox = [lon-0.5, lat-0.5, lon+0.5, lat+0.5]
    try:
        loc = geocoder.here(loc_name, bbox=bbox, app_id='xIirayHrtGRTzhFhowWm', app_code='PHY3HgiT4QsGtpMPUA_tRA').json
        regions['county_here'].loc[i]=loc['county']
        regions['state_here'].loc[i]=loc['state']
        regions['lon_here'].loc[i]=loc['lng']
        regions['lat_here'].loc[i]=loc['lat']
    except:
        print i
# Out:
# 1007
# 2550

# %%
loc = geocoder.here('Fort Meade', bbox=[-77.281064,38.551937, -76.281064,39.551937], app_id='xIirayHrtGRTzhFhowWm', app_code='PHY3HgiT4QsGtpMPUA_tRA').json
loc
# Out:
# {'address': u'Fort Meade, MD, United States',
#  'bbox': {'northeast': [39.13057, -76.7133],
#   'southwest': [39.08718, -76.77576]},
#  'city': u'Fort Meade',
#  'confidence': 6,
#  'country': u'USA',
#  'county': u'Anne Arundel',
#  'lat': 39.10667,
#  'lng': -76.73481,
#  'ok': True,
#  'postal': u'20755',
#  'raw': {u'Address': {u'AdditionalData': [{u'key': u'CountryName',
#      u'value': u'United States'},
#     {u'key': u'StateName', u'value': u'Maryland'},
#     {u'key': u'CountyName', u'value': u'Anne Arundel'},
#     {u'key': u'PostalCodeType', u'value': u'N'}],
#    u'City': u'Fort Meade',
#    u'Country': u'USA',
#    u'County': u'Anne Arundel',
#    u'Label': u'Fort Meade, MD, United States',
#    u'PostalCode': u'20755',
#    u'State': u'MD'},
#   u'CountryName': u'United States',
#   u'CountyName': u'Anne Arundel',
#   u'DisplayPosition': {u'Latitude': 39.10667, u'Longitude': -76.73481},
#   u'LocationId': u'NT_xn.Hk7jwjNG4J2d8xKgCsB',
#   u'LocationType': u'area',
#   u'MapView': {u'BottomRight': {u'Latitude': 39.08718, u'Longitude': -76.7133},
#    u'TopLeft': {u'Latitude': 39.13057, u'Longitude': -76.77576}},
#   u'NavigationPosition': [{u'Latitude': 39.10667, u'Longitude': -76.73481}],
#   u'PostalCodeType': u'N',
#   u'StateName': u'Maryland'},
#  'state': u'MD',
#  'status': 'OK'}

# %%
regions['county_here'].loc[1007]=loc['county']
regions['state_here'].loc[1007]=loc['state']
regions['lon_here'].loc[1007]=loc['lng']
regions['lat_here'].loc[1007]=loc['lat']

# %%
loc = geocoder.here('Saint Helena', bbox=[-80.859215,32.219252, -80.359215,32.719252], app_id='xIirayHrtGRTzhFhowWm', app_code='PHY3HgiT4QsGtpMPUA_tRA').json
loc
# Out:
# {'address': u'St Helena, SC, United States',
#  'bbox': {'northeast': [32.41043, -80.56067],
#   'southwest': [32.38345, -80.59263]},
#  'city': u'St Helena',
#  'confidence': 7,
#  'country': u'USA',
#  'county': u'Beaufort',
#  'lat': 32.39694,
#  'lng': -80.57665,
#  'ok': True,
#  'postal': u'29920',
#  'raw': {u'Address': {u'AdditionalData': [{u'key': u'CountryName',
#      u'value': u'United States'},
#     {u'key': u'StateName', u'value': u'South Carolina'},
#     {u'key': u'CountyName', u'value': u'Beaufort'},
#     {u'key': u'PostalCodeType', u'value': u'N'}],
#    u'City': u'St Helena',
#    u'Country': u'USA',
#    u'County': u'Beaufort',
#    u'Label': u'St Helena, SC, United States',
#    u'PostalCode': u'29920',
#    u'State': u'SC'},
#   u'CountryName': u'United States',
#   u'CountyName': u'Beaufort',
#   u'DisplayPosition': {u'Latitude': 32.39694, u'Longitude': -80.57665},
#   u'LocationId': u'NT_HKA077YK1NWVpEhYb8ru5C',
#   u'LocationType': u'area',
#   u'MapView': {u'BottomRight': {u'Latitude': 32.38345,
#     u'Longitude': -80.56067},
#    u'TopLeft': {u'Latitude': 32.41043, u'Longitude': -80.59263}},
#   u'NavigationPosition': [{u'Latitude': 32.39694, u'Longitude': -80.57665}],
#   u'PostalCodeType': u'N',
#   u'StateName': u'South Carolina'},
#  'state': u'SC',
#  'status': 'OK'}

# %%
regions['county_here'].loc[2550]=loc['county']
regions['state_here'].loc[2550]=loc['state']
regions['lon_here'].loc[2550]=loc['lng']
regions['lat_here'].loc[2550]=loc['lat']

# %% [markdown]
# Compare 2 methods. The second one is more accurate, so the results from the second one are adopted.

# %%
regions[regions['county'] != regions['county_here']]
# Out:
#                region name        lon        lat           county state  \
# 4               Aberdeen_4 -79.410768  35.054672             Hoke    NC
# 6               Accokeek_2 -77.020266  38.623478          Charles    MD
# 9                Adamstown -77.413075  39.174957       Montgomery    MD
# 11                Adrian_2 -82.694905  32.566149          Laurens    GA
# 12                Adrian_3 -82.661133  32.509754          Laurens    GA
# 16                 Afton_3 -78.706055  37.961515        Albemarle    VA
# 18               Ahoskie_1 -76.926994  36.208621           Bertie    NC
# 19               Ahoskie_2 -76.995230  36.224266           Bertie    NC
# 21                 Aiken_3 -81.508896  33.247739         Barnwell    SC
# 25                Albany_2 -82.229004  39.192518            Meigs    OH
# 26                Albany_3 -82.309570  39.222781           Vinton    OH
# 33              Alderson_2 -80.639648  37.683812           Monroe    WV
# 36            Alexandria_4 -77.141080  38.739530   Fairfax County    VA
# 41                    Alma -81.107528  39.340465        Pleasants    WV
# 46             Altavista_1 -79.247126  37.113301     Pittsylvania    VA
# 47                  Alto_1 -83.662013  34.386238             Hall    GA
# 58            Amissville_1 -78.003068  38.632621         Culpeper    VA
# 66                Angier_2 -78.616108  35.487051         Johnston    NC
# 68    Annapolis Junction_1 -76.801960  39.081352     Anne Arundel    MD
# 70                  Apex_1 -78.941141  35.770241          Chatham    NC
# 76                 Aquasco -76.671084  38.581340          Calvert    MD
# 78                Ararat_2 -80.543333  36.527013            Surry    NC
# 82             Arlington_1 -77.173344  38.697301   Fairfax County    VA
# 88             Arrington_2 -78.975730  37.664081          Amherst    VA
# 100               Ashton_2 -82.206539  38.529773           Cabell    WV
# 103               Athens_4 -83.469914  34.030246          Jackson    GA
# 104               Athens_6 -83.457552  33.872214           Oconee    GA
# 106               Atkins_1 -81.671462  36.714992       Washington    VA
# 116             Aulander_3 -77.065219  36.268023         Hertford    NC
# 119          Austinville_1 -80.796260  36.814073          Carroll    VA
# ...                    ...        ...        ...              ...   ...
# 3096           Whitakers_1 -77.562196  36.004126        Edgecombe    NC
# 3098         White Marsh_2 -76.544768  39.307218   Baltimore City    MD
# 3107          Whitesburg_3 -83.097171  36.272580          Hawkins    TN
# 3109         Whitesville_2 -81.476058  37.961127          Raleigh    WV
# 3115              Whitsett -79.538906  36.045971         Alamance    NC
# 3122             Willard_3 -78.178711  34.705486          Sampson    NC
# 3124        Williamsburg_1 -83.988612  39.104342            Brown    OH
# 3127        Williamsburg_5 -76.687338  37.242248       James City    VA
# 3128        Williamsburg_7 -76.632793  37.217153       James City    VA
# 3129        Williamsburg_9 -76.651190  37.281530             York    VA
# 3143              Wilson_1 -77.964316  35.822284             Nash    NC
# 3148          Winchester_2 -83.724546  38.960398            Brown    OH
# 3149          Winchester_5 -78.158676  39.071218        Frederick    VA
# 3150          Winchester_7 -78.117640  39.122302        Frederick    VA
# 3153              Winder_4 -83.638721  33.894190           Walton    GA
# 3154          Windsor Mill -76.794958  39.244695           Howard    MD
# 3164           Winnsboro_2 -81.176381  34.163230         Richland    SC
# 3166       Winston Salem_2 -80.246033  35.974172         Davidson    NC
# 3170                 Wirtz -79.767766  37.100709  Franklin County    VA
# 3172            Woodbine_1 -74.750977  39.334289         Atlantic    NJ
# 3183            Woodruff_3 -82.138094  34.768870          Laurens    SC
# 3185           Woodstock_2 -84.365485  34.091689           Fulton    GA
# 3201            Yeaddiss_1 -83.188477  37.055169            Perry    KY
# 3202            Yemassee_1 -80.780163  32.682856         Beaufort    SC
# 3203            Yemassee_2 -80.903480  32.556580           Jasper    SC
# 3204            Yemassee_3 -80.750453  32.499377         Beaufort    SC
# 3208        Young Harris_1 -83.928955  34.906545            Union    GA
# 3209         Youngsville_1 -78.492485  35.995216             Wake    NC
# 3211             Zebulon_3 -78.281564  35.767357         Johnston    NC
# 3213             Zebulon_5 -84.235286  33.095035            Lamar    GA
#
#          evacuation          county_here state_here  lon_here  lat_here
# 4     no evacuation                Moore         NC -79.42954  35.13139
# 6     no evacuation      Prince George's         MD -77.02287  38.67076
# 9     no evacuation            Frederick         MD -77.47508  39.31130
# 11    no evacuation              Emanuel         GA -82.59039  32.53105
# 12    no evacuation              Emanuel         GA -82.59039  32.53105
# 16    no evacuation               Nelson         VA -78.83915  38.03313
# 18    no evacuation             Hertford         NC -76.98960  36.28959
# 19    no evacuation             Hertford         NC -76.98960  36.28959
# 21    no evacuation                Aiken         SC -81.72214  33.56165
# 25    no evacuation               Athens         OH -82.20103  39.22491
# 26    no evacuation               Athens         OH -82.20103  39.22491
# 33    no evacuation           Greenbrier         WV -80.64309  37.72599
# 36    no evacuation    Alexandria (City)         VA -77.04342  38.80461
# 41    no evacuation                Tyler         WV -80.83927  39.42949
# 46    no evacuation             Campbell         VA -79.28916  37.10917
# 47    no evacuation                Banks         GA -83.57560  34.46611
# 58    no evacuation         Rappahannock         VA -78.00611  38.68135
# 66    no evacuation              Harnett         NC -78.74297  35.50736
# 68    no evacuation               Howard         MD -76.78750  39.12411
# 70    no evacuation                 Wake         NC -78.85435  35.73301
# 76    no evacuation      Prince George's         MD -76.72479  38.58370
# 78    no evacuation              Patrick         VA -80.51485  36.59667
# 82    no evacuation            Arlington         VA -77.08629  38.89051
# 88    no evacuation               Nelson         VA -78.90119  37.68296
# 100   no evacuation                Mason         WV -82.16364  38.62412
# 103   no evacuation               Clarke         GA -83.37326  33.95813
# 104   no evacuation               Clarke         GA -83.37326  33.95813
# 106   no evacuation                Smyth         VA -81.42310  36.86680
# 116   no evacuation               Bertie         NC -77.11397  36.22885
# 119   no evacuation                Wythe         VA -80.91477  36.85002
# ...             ...                  ...        ...       ...       ...
# 3096  no evacuation                 Nash         NC -77.71501  36.10523
# 3098  no evacuation            Baltimore         MD -76.41182  39.39234
# 3107  no evacuation              Hamblen         TN -83.13630  36.27326
# 3109  no evacuation                Boone         WV -81.53649  37.98240
# 3115  no evacuation             Guilford         NC -79.56423  36.06983
# 3122  no evacuation               Pender         NC -77.97970  34.68992
# 3124  no evacuation             Clermont         OH -84.06151  39.05874
# 3127  no evacuation  Williamsburg (City)         VA -76.71008  37.27564
# 3128  no evacuation  Williamsburg (City)         VA -76.71008  37.27564
# 3129  no evacuation  Williamsburg (City)         VA -76.71008  37.27564
# 3143  no evacuation               Wilson         NC -77.91638  35.72197
# 3148  no evacuation                Adams         OH -83.65186  38.94083
# 3149  no evacuation    Winchester (City)         VA -78.16405  39.18401
# 3150  no evacuation    Winchester (City)         VA -78.16405  39.18401
# 3153  no evacuation               Barrow         GA -83.72244  33.99125
# 3154  no evacuation            Baltimore         MD -76.75971  39.33359
# 3164  no evacuation            Fairfield         SC -81.08618  34.37963
# 3166  no evacuation              Forsyth         NC -80.24116  36.10002
# 3170  no evacuation             Franklin         VA -79.88687  37.07288
# 3172  no evacuation             Cape May         NJ -74.81342  39.23785
# 3183  no evacuation          Spartanburg         SC -82.03657  34.73996
# 3185  no evacuation             Cherokee         GA -84.51875  34.10292
# 3201  no evacuation               Leslie         KY -83.21863  37.06975
# 3202  no evacuation              Hampton         SC -80.84840  32.68820
# 3203  no evacuation              Hampton         SC -80.84840  32.68820
# 3204  no evacuation              Hampton         SC -80.84840  32.68820
# 3208  no evacuation                Towns         GA -83.84869  34.93312
# 3209  no evacuation             Franklin         NC -78.48109  36.02980
# 3211  no evacuation                 Wake         NC -78.31526  35.82528
# 3213  no evacuation                 Pike         GA -84.34166  33.09803
#
# [792 rows x 10 columns]

# %%
regions[regions['state'] != regions['state_here']]
# Out:
#            region name        lon        lat                county state  \
# 78            Ararat_2 -80.543333  36.527013                 Surry    NC
# 272           Bloomery -78.245841  39.231810             Frederick    VA
# 284        Bluefield_1 -81.380229  37.206102              Tazewell    VA
# 321           Bracey_2 -78.095734  36.535733                Warren    NC
# 328       Brandywine_3 -79.175302  38.559650            Rockingham    VA
# 330        Brasstown_2 -83.979665  34.962611                 Union    GA
# 332          Brentwood -76.966525  38.883680  District of Columbia    DC
# 346          Bristol_5 -82.240646  36.614540            Washington    VA
# 380        Bunker Hill -78.024493  39.259720                Clarke    VA
# 430             Cana_1 -80.602106  36.505427                 Surry    NC
# 497       Charles Town -77.751483  39.214042               Loudoun    VA
# 503        Charlotte_4 -80.844800  34.976344             Lancaster    SC
# 515       Chesapeake_1 -82.431359  38.428299                Cabell    WV
# 551      Clarks Hill_2 -82.090956  33.557560              Columbia    GA
# 559         Claudville -80.507689  36.546958                 Surry    NC
# 610       College Park -76.967452  38.934015  District of Columbia    DC
# 645         Copperhill -84.344150  34.989438                Fannin    GA
# 725         Danville_1 -79.418643  36.531363               Caswell    NC
# 929        Fair Play_1 -82.910758  34.466599                  Hart    GA
# 930        Fair Play_2 -83.023288  34.452766                  Hart    GA
# 1018   Fort Washington -77.037726  38.741784        Fairfax County    VA
# 1134        Glenwood_5 -82.308668  38.514946              Lawrence    OH
# 1264     Harpers Ferry -77.778761  39.170852               Loudoun    VA
# 1335         High View -78.312188  39.199811             Frederick    VA
# 1421         Ingleside -75.719222  39.129664                  Kent    DE
# 1426         Ironton_1 -82.646966  38.479939                  Boyd    KY
# 1487              Jolo -81.921277  37.312265              Buchanan    VA
# 1520          Kermit_1 -82.382197  37.809886                Martin    KY
# 1563       Knoxville_8 -77.540329  39.261777               Loudoun    VA
# 1564       Knoxville_9 -77.736133  39.300192               Loudoun    VA
# 1585         Lambsburg -80.705408  36.511419                 Surry    NC
# 1676  Little Hocking_2 -81.675684  39.256897                  Wood    WV
# 1784      Manchester_2 -83.710313  38.637471                 Mason    KY
# 1918           Milam_2 -79.136524  38.582715            Rockingham    VA
# 2053         Narrows_1 -81.093568  37.242408                 Bland    VA
# 2174           Otway_1 -83.015695  38.719774               Greenup    KY
# 2215           Paw Paw -78.311930  39.300796             Frederick    VA
# 2321          Portland -81.742555  38.888941               Jackson    WV
# 2340      Proctorville -82.348579  38.432697                Cabell    WV
# 2663   Silver Spring_1 -77.047030  38.984039  District of Columbia    DC
# 2673          Skippers -77.601846  36.528146           Northampton    NC
# 2744            Squire -81.542176  37.161815              Tazewell    VA
# 2886           Tillman -81.167669  32.323014             Effingham    GA
# 2910             Trade -81.758420  36.311727               Watauga    NC
# 2926             Tryon -82.208821  35.156459           Spartanburg    SC
# 2955        Valentines -77.755108  36.521674           Northampton    NC
# 3029             Warne -83.879634  34.962506                 Towns    GA
# 3042     Washington_11 -77.094544  38.781403        Fairfax County    VA
#
#          evacuation           county_here state_here  lon_here  lat_here
# 78    no evacuation               Patrick         VA -80.51485  36.59667
# 272   no evacuation             Hampshire         WV -78.37354  39.38669
# 284   no evacuation                Mercer         WV -81.22262  37.26798
# 321   no evacuation           Mecklenburg         VA -78.14607  36.59790
# 328   no evacuation             Pendleton         WV -79.24439  38.62489
# 330   no evacuation                  Clay         NC -83.95815  35.03950
# 332   no evacuation       Prince George's         MD -76.95530  38.94290
# 346   no evacuation              Sullivan         TN -82.22129  36.59218
# 380   no evacuation              Berkeley         WV -78.05280  39.33615
# 430   no evacuation               Carroll         VA -80.67181  36.58938
# 497   no evacuation             Jefferson         WV -77.85909  39.28935
# 503   no evacuation           Mecklenburg         NC -80.83796  35.22287
# 515   no evacuation              Lawrence         OH -82.46276  38.42693
# 551   no evacuation             McCormick         SC -82.17172  33.66812
# 559   no evacuation               Patrick         VA -80.41810  36.58993
# 610   no evacuation       Prince George's         MD -76.93727  38.98073
# 645   no evacuation                  Polk         TN -84.37094  34.98872
# 725   no evacuation       Danville (City)         VA -79.41721  36.58598
# 929   no evacuation                Oconee         SC -82.98670  34.51110
# 930   no evacuation                Oconee         SC -82.98670  34.51110
# 1018  no evacuation       Prince George's         MD -77.00058  38.74059
# 1134  no evacuation                 Mason         WV -82.18321  38.59384
# 1264  no evacuation             Jefferson         WV -77.73907  39.32546
# 1335  no evacuation             Hampshire         WV -78.40646  39.23287
# 1421  no evacuation           Queen Annes         MD -75.87050  39.11440
# 1426  no evacuation              Lawrence         OH -82.68401  38.53517
# 1487  no evacuation              McDowell         WV -81.82011  37.32383
# 1520  no evacuation                 Mingo         WV -82.40846  37.84187
# 1563  no evacuation             Frederick         MD -77.66513  39.32720
# 1564  no evacuation             Frederick         MD -77.66513  39.32720
# 1585  no evacuation               Carroll         VA -80.75841  36.58454
# 1676  no evacuation            Washington         OH -81.69934  39.26140
# 1784  no evacuation                 Adams         OH -83.60253  38.68852
# 1918  no evacuation                 Hardy         WV -79.07378  38.84096
# 2053  no evacuation                Mercer         WV -81.00975  37.42242
# 2174  no evacuation                Scioto         OH -83.18838  38.86558
# 2215  no evacuation                Morgan         WV -78.45711  39.53454
# 2321  no evacuation                 Meigs         OH -81.77389  39.00140
# 2340  no evacuation              Lawrence         OH -82.37779  38.43796
# 2663  no evacuation            Montgomery         MD -77.02914  38.99693
# 2673  no evacuation           Greensville         VA -77.55318  36.62086
# 2744  no evacuation              McDowell         WV -81.60940  37.23734
# 2886  no evacuation                Jasper         SC -81.13279  32.46940
# 2910  no evacuation               Johnson         TN -81.72549  36.36328
# 2926  no evacuation                  Polk         NC -82.24143  35.21296
# 2955  no evacuation             Brunswick         VA -77.81621  36.58600
# 3029  no evacuation                  Clay         NC -83.88364  34.99891
# 3042  no evacuation  District of Columbia         DC -77.03196  38.89037

# %%
regions = regions.drop(columns=['state', 'county', 'lon', 'lat'])

# %%
regions = regions.rename(columns={'state_here':'state', 'county_here':'county', 'lon_here':'lon', 'lat_here':'lat'})

# %% [markdown]
# Now, identify evacuation status for each city.

# %%
regions['evacuation'] = 'no evacuation'

# %%
# Beaufort, NC
regions['evacuation'][(regions['county']=='Beaufort') & (regions['state']=='NC')] = 'mandatory to voluntary'
regions['evacuation'][(regions['region name'].str.contains('bayview|belhaven|bath|whitepost|river\sroad|river\srd|washington|chocowinity|aurora', 
                                                           case=False))&(regions.county=='Beaufort')&(regions.state=='NC')]='mandatory'
# Out:
# /anaconda2/envs/Py27/lib/python2.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /anaconda2/envs/Py27/lib/python2.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.

# %%
# Bertie, NC
regions['evacuation'][(regions['region name'].str.contains('colerain|whites\sbeach|ashland|avoca|merry\shill', case=False))&(regions.county=='Bertie')&(regions.state=='NC')]='voluntary'
# Out:
# /anaconda2/envs/Py27/lib/python2.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
# Brunswick, NC
Brunswick_unincorporated = 'Sunset\sHarbor|Supply|Winnabow'
voluntary = 'Leland|Navassa'
visitor = 'Holden\sBeach|Oak\sIsland|Bald|Caswell|Ocean|Sunset|Bird'
regions['evacuation'][(regions['region name'].str.contains(visitor, case=False))&(regions.county=='Brunswick')&(regions.state=='NC')]='mandatory (visitor)'
regions['evacuation'][(regions['region name'].str.contains(Brunswick_unincorporated, case=False))&(regions.county=='Brunswick')&(regions.state=='NC')]='mandatory'
regions['evacuation'][(regions['region name'].str.contains(voluntary, case=False))&(regions.county=='Brunswick')&(regions.state=='NC')]='voluntary'
# Out:
# /anaconda2/envs/Py27/lib/python2.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
# /anaconda2/envs/Py27/lib/python2.7/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /anaconda2/envs/Py27/lib/python2.7/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys

# %%
# Carteret, NC
regions['evacuation'][(regions['region name'].str.contains('Atlantic\sBeach|Emerald\sIsle|Indian\sBeach|Pine\sKnoll\sShores', case=False))&(regions.county=='Carteret')&(regions.state=='NC')]='mandatory'
# Out:
# /anaconda2/envs/Py27/lib/python2.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
# Columbus, NC
regions['evacuation'][(regions['county']=='Columbus') & (regions['state']=='NC')] = 'voluntary'
# Out:
# /anaconda2/envs/Py27/lib/python2.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
# Craven, NC
regions['evacuation'][(regions['county']=='Craven') & (regions['state']=='NC')] = 'mandatory'
# Out:
# /anaconda2/envs/Py27/lib/python2.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
# Currituck, NC
regions['evacuation'][(regions['region name'].str.contains('Corolla|Carova'))&(regions['county']=='Currituck') & (regions['state']=='NC')] = 'mandatory'
# Out:
# /anaconda2/envs/Py27/lib/python2.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
# Dare, NC
regions['evacuation'][(regions['county']=='Dare') & (regions['state']=='NC')] = 'mandatory'
# Out:
# /anaconda2/envs/Py27/lib/python2.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
# Duplin, NC
regions['evacuation'][(regions['county']=='Duplin') & (regions['state']=='NC')] = 'voluntary'
# Out:
# /anaconda2/envs/Py27/lib/python2.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
# Hyde, NC
regions['evacuation'][(regions['region name'].str.contains('Ocracoke'))&(regions['county']=='Hyde') & (regions['state']=='NC')] = 'mandatory'
# Out:
# /anaconda2/envs/Py27/lib/python2.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
# Jones, NC
regions['evacuation'][(regions['county']=='Jones') & (regions['state']=='NC')] = 'mandatory'
# Out:
# /anaconda2/envs/Py27/lib/python2.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
# Lenoir, NC
regions['evacuation'][(regions['county']=='Lenoir') & (regions['state']=='NC')] = 'voluntary'
# Out:
# /anaconda2/envs/Py27/lib/python2.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
# New Hanover, NC
regions['evacuation'][(regions['county']=='New Hanover') & (regions['state']=='NC')] = 'voluntary'
regions['evacuation'][(regions['region name'].str.contains('Carolina\sBeach|Kure\sBeach|Wrightsville\sBeach|Wilmington'))&(regions['county']=='New Hanover') & (regions['state']=='NC')] = 'mandatory'
# Out:
# /anaconda2/envs/Py27/lib/python2.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /anaconda2/envs/Py27/lib/python2.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
# Onslow, NC
voluntary = 'Half\sMoon|Petersburg|Piney\sGreen|Pumpkin\sCenter|Sneads\sFerry|Surf'
regions['evacuation'][(regions['region name'].str.contains(voluntary))&(regions['county']=='Onslow') & (regions['state']=='NC')] = 'voluntary'
regions['evacuation'][(regions['region name'].str.contains('Topsail\sBeach'))&(regions['county']=='Onslow') & (regions['state']=='NC')] = 'mandatory'
# Out:
# /anaconda2/envs/Py27/lib/python2.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /anaconda2/envs/Py27/lib/python2.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.

# %%
# Pamlico, NC
regions['evacuation'][(regions['county']=='Pamlico') & (regions['state']=='NC')] = 'mandatory'
# Out:
# /anaconda2/envs/Py27/lib/python2.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
# Pender, NC
regions['evacuation'][(regions['region name'].str.contains('Topsail|Surf|Sloop'))&(regions['county']=='Pender') & (regions['state']=='NC')] = 'voluntary'
# Out:
# /anaconda2/envs/Py27/lib/python2.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
# Tyrrell, NC
regions['evacuation'][(regions['county']=='Tyrrell') & (regions['state']=='NC')] = 'mandatory'
# Out:
# /anaconda2/envs/Py27/lib/python2.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
# SC
m_to_no = 'Beaufort|Colleton|Jasper'
mandatory = 'Dorchester|Berkeley|Charleston|Georgetown|Horry'
regions['evacuation'][(regions['county'].str.contains(m_to_no)) & (regions['state']=='SC')] = 'mandatory to no evacuation'
regions['evacuation'][(regions['county'].str.contains(mandatory)) & (regions['state']=='SC')] = 'mandatory'
regions['evacuation'][(regions['region name'].str.contains('Edisto\sBeach', case=False))&(regions['county']=='Beaufort') & (regions['state']=='SC')] = 'mandatory'
# Out:
# /anaconda2/envs/Py27/lib/python2.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# /anaconda2/envs/Py27/lib/python2.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
# /anaconda2/envs/Py27/lib/python2.7/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
#VA
import folium
m = folium.Map(location=[35.7596, -79.0193], zoom_start=6)
names = regions['region name'].str.replace('_.+County_.+', '').str.replace('[&\']', '')
for i in regions[regions['state']=='VA'].index:
    lat = regions['lat'].loc[i]
    lon = regions['lon'].loc[i]
    folium.Circle(
        radius=200,
        location=[lat, lon],
        #tooltip = names.iloc[i],
        popup = folium.Popup(names.loc[i],parse_html=True)
    ).add_to(m)

# %%
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
ZoneA='Cape\sCharles|Chincoteague|Port\sHaywood|Quiet\sCove|Seaford_1|Poquoson_2|Gloucester_1|Water\sView|Hampton_5|Smithfield_1|Suffolk_4|Norfolk_3|Portsmouth_4|Chesapeake_2|Virginia\sBeach_3'

# %%
regions['evacuation'][(regions['region name'].str.contains(ZoneA)) & (regions['state']=='VA')] = 'mandatory'
# Out:
# /anaconda2/envs/Py27/lib/python2.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
regions.evacuation.value_counts()
# Out:
# no evacuation                 3030
# mandatory                      118
# voluntary                       39
# mandatory to no evacuation      24
# mandatory to voluntary           4
# mandatory (visitor)              2
# Name: evacuation, dtype: int64

# %%
regions.to_csv('cleansed_data/evacuation.csv')

# %%
m = folium.Map(location=[35.7596, -79.0193], zoom_start=6)
names = regions['region name'].str.replace('_.+County_.+', '').str.replace('[&\']', '')
colors = {'mandatory':'crimson', 'voluntary':'darkgreen', 'mandatory to no evacuation':'yellow',
         'mandatory to voluntary':'yellow', 'mandatory (visitor)':'black', 'no evacuation':'blue'}
for i in regions.index:
    lat = regions['lat'].loc[i]
    lon = regions['lon'].loc[i]
    folium.Circle(
        radius=100,
        location=[lat, lon],
        color=colors[regions['evacuation'].loc[i]],
        popup=folium.Popup(names.loc[i], parse_html=True)
    ).add_to(m)

# %%
m.save('evacuation.html')
